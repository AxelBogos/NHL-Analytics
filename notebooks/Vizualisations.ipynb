# %% [markdown]
# # Visualizations <br>
# ### The objectives of this notebook are:
# * **Import** our plotting functions from ```plots.py```;
# * **Display** visualizations;
# * **Discuss** insights observable from the visualizations.

# %% [markdown]
# ## Imports

# %%
from src import plots

# %% [markdown]
# ## Shot-type Histogram

# %%
plots.shot_type_histogram()

# %% [markdown]
# ## Other plot

# %% [markdown]
# ## Other plot
